# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

filterwarnings("ignore")
# %matplotlib inline
df= pd.read_csv("C:\\Users\\Aman Ullah\\Desktop\\amazon.csv")
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
plt.subplot(1, 1, 1)
sns.histplot(data['rating_count'], bins=30, kde=True, color='orange')
plt.title('Distribution of Rating Count')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.histplot(data['rating'], bins=20, kde=True, color='blue')
plt.title('Distribution of Ratings')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 25))


plt.subplot(3, 2, 1)
sns.heatmap(data[['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')


plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.boxplot(data=data[['discounted_price', 'actual_price']])
plt.title('Price Comparison')
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
top_discounted = data.nlargest(10, 'discounted_price')[['product_name', 'discounted_price']]
sns.barplot(y=top_discounted['product_name'], x=top_discounted['discounted_price'], palette='magma')
plt.title('Top 10 Products by Discounted Price')
plt.xlabel('Discounted Price')
plt.ylabel('Product Name')
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.scatterplot(x=data['actual_price'], y=data['discounted_price'], hue=data['rating'], palette='cool', alpha=0.6)
plt.title('Actual Price vs Discounted Price')
plt.xlabel('Actual Price')
plt.ylabel('Discounted Price')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Product Distribution Across Categories (Pie Chart)')
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('muted'))
center_circle = plt.Circle((0, 0), 0.70, fc='white')  # Add a white circle in the center
fig = plt.gcf()
fig.gca().add_artist(center_circle)
plt.title('Product Distribution Across Categories (Donut Chart)')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.scatterplot(x=data['actual_price'], y=data['discounted_price'], alpha=0.7, color='green')
plt.title('Actual Price vs Discounted Price')
plt.xlabel('Actual Price')
plt.ylabel('Discounted Price')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
top_categories = data['category'].value_counts().head(10)
sns.barplot(y=top_categories.index, x=top_categories.values, palette='viridis')
plt.title('Top Categories by Product Count')
plt.xlabel('Count')
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.scatterplot(x=data['discount_percentage'], y=data['rating'], alpha=0.6, color='purple')
plt.title('Discount Percentage vs Rating')
plt.xlabel('Discount Percentage')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
product_id:  Unique identifier for each product.
product_name:  Name of the product.
category:  Category of the product.
discounted_price:  Discounted price of the product .
actual_price:  Original price of the product .
discount_percentage:  Percentage discount on the product.
rating:  Average rating of the product.
rating_count:  Total number of ratings received.
about_product:  Description or additional information about the product.
user_id:  Unique identifier for the user who left a review.
user_name:  Name of the user who left a review.
review_id:  Unique identifier for the review.
review_title:  Title of the review.
review_content:  Full text of the review.
img_link:  URL link to the product image.
product_link:  URL link to the product page

# %%
Conclusion from the Dataset Analysis:
Ratings Distribution:
Most products have moderate to high ratings, indicating customer satisfaction. Few products fall into lower rating categories.

Pricing Insights:
The difference between actual price and discounted price shows significant discounts, which might attract customers. Outliers exist with high discounted prices.

Discount Patterns:
A majority of products offer discounts in a consistent range, with some exceptional products having very high discounts.

Top Categories:
Certain product categories dominate the dataset, with the top 10 categories accounting for a significant portion of the products.

Relationships:
Discount Percentage vs Rating: No strong relationship, suggesting high discounts don’t always guarantee better ratings.
Actual Price vs Discounted Price: Products with higher original prices tend to have higher discounted prices, maintaining a proportional relationship.
    
Customer Engagement:
The distribution of rating counts shows a skew, with some products being reviewed significantly more than others.

Visual Highlights:
Correlation heatmaps indicate a moderate relationship between certain variables (e.g., discount percentage and price). However, ratings show weak correlations with other numeric features.

Recommendations:
    
Targeted Promotions: Focus on highly discounted products with moderate ratings for improvement in customer engagement.
    
Category Insights: Diversify offerings in under-represented categories for a balanced portfolio.
    
Customer Feedback: Address feedback for products with low ratings despite high sales or discounts to improve trust.

# %%
Summary of Dataset Analysis
The analysis of the dataset reveals valuable insights about product pricing, customer ratings,
 and category distribution. Most products in the dataset are priced competitively, with 
 significant discounts offered across categories. Customer ratings are generally positive, 
 although discounts do not directly correlate with higher ratings.

Key findings include:

Ratings: Products generally receive favorable reviews, with only a few outliers having low ratings.
Pricing: Discounted prices align proportionally with actual prices, reflecting structured pricing strategies.
Categories: A few product categories dominate the offerings, with the top 10 categories accounting for a majority of the products.
Discount Patterns: Discounts are prevalent but do not strongly influence customer ratings.
Customer Engagement: A small proportion of products attract the majority of ratings and reviews.
